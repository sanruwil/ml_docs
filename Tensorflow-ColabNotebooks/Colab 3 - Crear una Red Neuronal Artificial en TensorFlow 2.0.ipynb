# %% [markdown]
# <a href="https://colab.research.google.com/github/joanby/tensorflow2/blob/master/Colab%203%20-%20Crear%20una%20Red%20Neuronal%20Artificial%20en%20TensorFlow%202.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="center">
#   <img src="https://storage.googleapis.com/kaggle-datasets-images/2243/3791/9384af51de8baa77f6320901f53bd26b/dataset-cover.png" />
#   Imagen cortesía de: https://www.kaggle.com/
# </p>

# %% [markdown]
# ## Paso 1: Instalar las dependencias y configurar el entorno de GPU

# %%
#!pip install tensorflow-gpu==2.3.0
# %tensorflow_version 2.x

# %% [markdown]
# ## Paso 2: Importar las dependencias necesarias para el proyecto

# %%
import numpy as np
import datetime
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

# %%
tf.__version__
# Out:
# '2.4.1'

# %% [markdown]
# ## Paso 3: Pre procesado de datos

# %% [markdown]
# ### Cargar el dataset

# %%
#Cargar el dataset Fashion Mnist 
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# ### Normalizar las imágenes
#
# Se divide cada imagen en los conjunto de entrenamiento y  de testing entre el valor máximo de cada uno de los píxeles (255).
#
# De este modo, cada píxel se hallará en el rango [0, 1]. Al normalizar las imágenes, nos aseguramos que nuestro modelo de RNA entrenará más rápidamente.

# %%
X_train = X_train / 255.0

# %%
X_test = X_test / 255.0

# %% [markdown]
# ### Redimensionar el dataset
#
# Como vamos a utilizar una red neuronal totalmente conectada, vamos a redimensionar los subconjuntos de entrenamiento y testing a formato de vector en lugar de en formato de matriz.

# %%
#Como cada imagen tiene 28x28 píxeles, usamos la función reshape en todo el dataset de entrenamiento para convertirlo 
# en vectores de tamaño [-1 (todos los elementos), anchura * altura]
X_train = X_train.reshape(-1, 28*28)

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
#Redimensionamos el conjunto de testing del mismo modo
X_test = X_test.reshape(-1, 28*28)

# %% [markdown]
# ## Paso 4: Construir la Red Neuronal Artificial

# %% [markdown]
# ### Definir el modelo
#
# Simplemente se define un objeto de modelo Sequential.

# %%
model = tf.keras.models.Sequential()

# %% [markdown]
# ### Añadir la primera capa totalmente conectada (capa Densa)
#
# Hyper-parametros de la capa:
# - número de unidades/neuronas: 128
# - función de activación: ReLU
# - input_shape: (784, )

# %%
model.add(tf.keras.layers.Dense(units=128, activation='sigmoid', input_shape=(784, )))

# %% [markdown]
# ### Añadir una capa de Dropout
#
# Dropout es una técnica de Regularization donde aleatoriamente se asignan a ciertas neuronas de la red el valor cero. De este modo, mientras se entrena, estas neuronas no actualizarán sus valores. Al tener cierto porcentaje de neuronas sin actualizar, el proceso de entrenamiento toma más tiempo pero por contra tenemos menos posibilidades de sufrir overfitting.

# %%
model.add(tf.keras.layers.Dropout(0.2))

# %% [markdown]
# ### Añadir la segunda capa (capa de salida)
#
# - unidades: número de clases (10 en el caso del Fashion MNIST)
# - función de activación: 'softmax' (probabilidades de cada clase)

# %%
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

# %% [markdown]
# ### Compilar el modelo
#
# - Optimizer: Adam
# - Loss: Sparse softmax (categorical) crossentropy

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               1408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               1408
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                1290
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               1408
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                1290
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               1408
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                1290
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               1408
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 248,490
# Trainable params: 248,490
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Entrenar el modelo

# %%
model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 7s 3ms/step - loss: 1.5476 - sparse_categorical_accuracy: 0.4691
# Epoch 2/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5610 - sparse_categorical_accuracy: 0.8509
# Epoch 3/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4740 - sparse_categorical_accuracy: 0.8781
# Epoch 4/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3898 - sparse_categorical_accuracy: 0.9013
# Epoch 5/50
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2919 - sparse_categorical_accuracy: 0.9233
# Epoch 6/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2466 - sparse_categorical_accuracy: 0.9314
# Epoch 7/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2716 - sparse_categorical_accuracy: 0.9245
# Epoch 8/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2416 - sparse_categorical_accuracy: 0.9309
# Epoch 9/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2407 - sparse_categorical_accuracy: 0.9296
# Epoch 10/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2402 - sparse_categorical_accuracy: 0.9316
# Epoch 11/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2244 - sparse_categorical_accuracy: 0.9346
# Epoch 12/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2314 - sparse_categorical_accuracy: 0.9318
# Epoch 13/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2466 - sparse_categorical_accuracy: 0.9271
# Epoch 14/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2436 - sparse_categorical_accuracy: 0.9286
# Epoch 15/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2519 - sparse_categorical_accuracy: 0.9255
# Epoch 16/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2312 - sparse_categorical_accuracy: 0.9309
# Epoch 17/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2341 - sparse_categorical_accuracy: 0.9287
# Epoch 18/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2437 - sparse_categorical_accuracy: 0.9284
# Epoch 19/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2140 - sparse_categorical_accuracy: 0.9309
# Epoch 20/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2362 - sparse_categorical_accuracy: 0.9291
# Epoch 21/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2598 - sparse_categorical_accuracy: 0.9247
# Epoch 22/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2513 - sparse_categorical_accuracy: 0.9242
# Epoch 23/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2309 - sparse_categorical_accuracy: 0.9319
# Epoch 24/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2210 - sparse_categorical_accuracy: 0.9334
# Epoch 25/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2509 - sparse_categorical_accuracy: 0.9269
# Epoch 26/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2323 - sparse_categorical_accuracy: 0.9304
# Epoch 27/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2395 - sparse_categorical_accuracy: 0.9299
# Epoch 28/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2809 - sparse_categorical_accuracy: 0.9225
# Epoch 29/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2428 - sparse_categorical_accuracy: 0.9294
# Epoch 30/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2449 - sparse_categorical_accuracy: 0.9270
# Epoch 31/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2479 - sparse_categorical_accuracy: 0.9257
# Epoch 32/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2849 - sparse_categorical_accuracy: 0.9199
# Epoch 33/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2515 - sparse_categorical_accuracy: 0.9274
# Epoch 34/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2537 - sparse_categorical_accuracy: 0.9281
# Epoch 35/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2596 - sparse_categorical_accuracy: 0.9216
# Epoch 36/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2535 - sparse_categorical_accuracy: 0.9267
# Epoch 37/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2618 - sparse_categorical_accuracy: 0.9230
# Epoch 38/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2668 - sparse_categorical_accuracy: 0.9223
# Epoch 39/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2682 - sparse_categorical_accuracy: 0.9248
# Epoch 40/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2615 - sparse_categorical_accuracy: 0.9260
# Epoch 41/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2493 - sparse_categorical_accuracy: 0.9258
# Epoch 42/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2419 - sparse_categorical_accuracy: 0.9296
# Epoch 43/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2543 - sparse_categorical_accuracy: 0.9274
# Epoch 44/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2771 - sparse_categorical_accuracy: 0.9211
# Epoch 45/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2786 - sparse_categorical_accuracy: 0.9221
# Epoch 46/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2515 - sparse_categorical_accuracy: 0.9249
# Epoch 47/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2884 - sparse_categorical_accuracy: 0.9201
# Epoch 48/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2806 - sparse_categorical_accuracy: 0.9218
# Epoch 49/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2531 - sparse_categorical_accuracy: 0.9280
# Epoch 50/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2662 - sparse_categorical_accuracy: 0.9231

# %% [markdown]
# ### Evaluación del modelo y predicción

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4566 - sparse_categorical_accuracy: 0.8774

# %%
print("Test accuracy: {}".format(test_accuracy))
# Out:
# Test accuracy: 0.8773999810218811

# %% [markdown]
# ## Paso 5 : Guardar el modelo

# %% [markdown]
# ### Guardar la arquitectura (topoligía) de la red neuronal

# %%
model_json = model.to_json()
with open("fashion_model.json", "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# ### Guardar los pesos de la red neuronal

# %%
model.save_weights("fashion_model.h5")

# %% [markdown]
# # Sección nueva
